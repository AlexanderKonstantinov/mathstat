# %% [markdown]
# ## Урок 1. Случайные события. Условная вероятность. Формула Байеса. Независимые испытания

# %% [markdown]
# ### 1. Из колоды в 52 карты извлекаются случайным образом 4 карты.
# ### a) Найти вероятность того, что все карты – крести.

# %% [markdown]
# ### Решение:
# $$ P(A)=\frac{m}{n} $$
# P(A) - вероятность того, что все карты окажутся крестовой масти,
# m - количество исходов, при которых все 4 карты будут крестовой масти,
# n - количество всех возможных исходов
#
# $$ m=\frac{13!}{4!(13-4)!}=\frac{10\cdot11\cdot12\cdot13}{24}=715 $$
#
# $$ n=\frac{(52-13)!}{4!(52-13-4)!}=\frac{39!}{4!\cdot35!}=82251 $$
#
# $$ P(A)=\frac{715}{82251}=0.008692903429745534 $$

# %% [markdown]
# ### б) Найти вероятность, что среди 4-х карт окажется ХОТЯ БЫ один туз.

# %% [markdown]
# ### Решение:
# $$ P(A)=\frac{m}{n} $$
# P(A) - вероятность того, что среди 4-х карт окажется туз,
# m - количество исходов, при которых одна из 4-х карт будет тузом,
# n - количество всех возможных исходов
#
# $$ m=4 $$
#
# $$ n=\frac{(52-4)!}{4!(52-4-4)!}=\frac{48!}{4!\cdot44!}=194580 $$
#
# $$ P(A)=\frac{4}{194580}= 0.000020557097337855894 $$
#
# ### Ответ: а) 0.008692903429745534  б) 0.000020557097337855894

# %% [markdown]
# ### 2. На входной двери подъезда установлен кодовый замок, содержащий десять кнопок с цифрами от 0 до 9. Код содержит три цифры, которые нужно нажать одновременно. Какова вероятность того, что человек, не знающий код, откроет дверь с первой попытки?

# %% [markdown]
# ### Решение:
# $$ P(A)=\frac{m}{n} $$
# P(A) - вероятность открытия двери,
# m - количество правильных кодов,
# n - количество всех возможных кодов из неповторяющихся цифр
#
# $$ m=1 $$
#
# $$ n=\frac{10!}{3!(10-3)!}=\frac{8\cdot9\cdot10}{6}=120 $$
#
# $$ P(A)=\frac{1}{120}=0.008333333333333333 $$
#
# ### Ответ: 0.008333333333333333

# %% [markdown]
# ### 3. В ящике имеется 15 деталей, из которых 9 окрашены. Рабочий случайным образом извлекает 3 детали. Какова вероятность того, что все извлеченные детали окрашены?

# %% [markdown]
# ### Решение:
# $$ P(A)=\frac{9}{15}\cdot\frac{8}{14}\cdot\frac{7}{13}=0.18461538461538463 $$
#
# ### Ответ: 0.18461538461538463

# %% [markdown]
# ### 4. В лотерее 100 билетов. Из них 2 выигрышных. Какова вероятность того, что 2 приобретенных билета окажутся выигрышными?

# %% [markdown]
# ### Решение:
# $$ P(A)=\frac{2}{100}\cdot\frac{1}{99}=0.00020202020202020202 $$
#
# ### Ответ: 0.00020202020202020202
