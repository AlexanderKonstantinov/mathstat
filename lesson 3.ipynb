# %%
from math import factorial, sqrt
import numpy as np

# %%
def combinations(n, k):
    return int(factorial(n) / (factorial(k) * factorial(n - k)))

# %% [markdown]
# ## Урок 3. Описательная статистика. Качественные и количественные характеристики популяции. Графическое представление данных

# %% [markdown]
# ### 1. Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %%
sample = np.array([100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150])
n = sample.shape[0]

# %%
M = sample.sum() / n

root_sum = sum(map(lambda x: pow(x - M, 2), sample))

square_S_1 = root_sum / n
square_S_2 = root_sum / (n - 1)

S = sqrt(square_S_2)

# %%
print(
f'''
Среднее арифметическое M = {M}
Среднее квадратичное отклонение выборки S = {S}
Смещенная дисперсия Sсм^2 = {square_S_1}
Несмещенная дисперсия Sн^2 = {square_S_2}
''')
# Out:
# Среднее арифметическое M = 65.3
# Среднее квадратичное отклонение выборки S = 31.624607341019814
# Смещенная дисперсия Sсм^2 = 950.11
# Несмещенная дисперсия Sн^2 = 1000.1157894736842

# %% [markdown]
# ### 2. В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %% [markdown]
# ### Решение:
#
# Пусть
#
# $ P_1 - $ вероятность вытащить из первого ящика 2 белых мяча и из второго 1 белый и 3 не белых
# $ P_2 - $ вероятность вытащить из первого ящика 1 белый мяч и 1 не белый и из второго 2 белых и 2 не белых
# $ P_3 - $ вероятность вытащить из первого ящика 0 белых мячей и из второго 3 белых мяча и 1 не белый

# %%
P_1 = combinations(5, 2) / combinations(8, 2) * combinations(5, 1) * combinations(7, 3) / combinations(12, 4)
P_2 = combinations(5, 1) * combinations(3, 1) / combinations(8, 2) * combinations(5, 2) * combinations(7, 2) / combinations(12, 4)
P_3 = combinations(3, 2) / combinations(8, 2) * combinations(5, 3) * combinations(7, 1) / combinations(12, 4)

P = P_1 + P_2 + P_3

# %%
print(f'P_1 = {P_1}\nP_2 = {P_2}\nP_3 = {P_3}\nP = {P}')
# Out:
# P_1 = 0.12626262626262627
# P_2 = 0.22727272727272724
# P_3 = 0.015151515151515152
# P = 0.3686868686868686

# %% [markdown]
# ### 3. На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.

# %% [markdown]
# ### Решение:
#
# Пусть
#
# $ P(B_1) - $ вероятность, что выстрел произведен первым спортсменом
# $ P(B_2) - $ вероятность, что выстрел произведен вторым спортсменом
# $ P(B_3) - $ вероятность, что выстрел произведен третьим спортсменом
#
# тогда воспользуемся формулой Байеса
#
# $ P(B_1) = \frac{\frac{0.9}{3}}{\frac{0.9}{3}\cdot\frac{0.8}{3}\cdot\frac{0.6}{3}} $

# %%
Pb_1 = (0.9 / 3) / ((0.9 + 0.8 + 0.6) / 3)
Pb_2 = (0.8 / 3) / ((0.9 + 0.8 + 0.6) / 3)
Pb_3 = (0.6 / 3) / ((0.9 + 0.8 + 0.6) / 3)

# %%
print(
f'''
а) Вероятность, что выстрел произведен первым спортсменом составляет {Pb_1}
б) Вероятность, что выстрел произведен вторым спортсменом составляет {Pb_2}
в) Вероятность, что выстрел произведен третьим спортсменом составляет {Pb_3}

Проверка: Вероятность, что выстрел совершил один из трех спортсменов составляет {P_A + P_B + P_C}
''')
# Out:
# а) Вероятность, что выстрел произведен первым спортсменом составляет 0.3913043478260869
# б) Вероятность, что выстрел произведен вторым спортсменом составляет 0.34782608695652173
# в) Вероятность, что выстрел произведен третьим спортсменом составляет 0.26086956521739124
#
# Проверка: Вероятность, что выстрел совершил один из трех спортсменов составляет 1.0

# %% [markdown]
# ### 4. В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %% [markdown]
# Решение:
# Пусть
#
# $ 𝑃(A) − $ вероятность, что студент учится на факультете A
# $ 𝑃(𝐵) − $ вероятность, что студент учится на факультете B
# $ 𝑃(C) − $ вероятность, что студент учится на факультете C
#
# $ p_1 - $ априорная вероятность, что студент учится на факультете A
# $ p_2 - $ априорная вероятность, что студент учится на факультете B
# $ p_3 - $ априорная вероятность, что студент учится на факультете C
#
# тогда воспользуемся формулой Байеса

# %%
p_1 = 0.25
p_2 = 0.25
p_3 = 0.5

P_A = (0.8 * p_1) / (0.8 * p_1 + 0.7 * p_2 + 0.9 * p_3)
P_B = (0.7 * p_2) / (0.8 * p_1 + 0.7 * p_2 + 0.9 * p_3)
P_C = (0.9 * p_3) / (0.8 * p_1 + 0.7 * p_2 + 0.9 * p_3)

# %%
print(
f'''
а) Вероятность, что студент учится на факультете A составляет {P_A}
б) Вероятность, что студент учится на факультете A составляет {P_B}
в) Вероятность, что студент учится на факультете A составляет {P_C}

Проверка: Вероятность, что студент учится на одном из трех факультетов составляет {P_A + P_B + P_C}
''')
# Out:
# а) Вероятность, что студент учится на факультете A составляет 0.24242424242424246
# б) Вероятность, что студент учится на факультете A составляет 0.21212121212121213
# в) Вероятность, что студент учится на факультете A составляет 0.5454545454545455
#
# Проверка: Вероятность, что студент учится на одном из трех факультетов составляет 1.0

# %% [markdown]
# ### 5. Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %% [markdown]
# ### Решение:
# Пусть
#
# $ P_1 - $ вероятность выхода из строя всех деталей
# $ P_2 - $ вероятность выхода из строя двух деталей
# $ P_3 - $ вероятность выхода из строя хотя бы одной детали
# $ P_4 - $ вероятность выхода из строя одной или двух деталей

# %%
P_1 = 0.1 * 0.2 * 0.25
P_2 = 0.1 * 0.2 + 0.1 * 0.25 + 0.2 * 0.25
P_3 = 1 - (1 - 0.1) * (1 - 0.2) * (1 - 0.25)
P_4 = P_3 - P_1

# %%
print(
f'''
а) Вероятность выхода из строя всех деталей составляет {P_1}
б) Вероятность выхода из строя двух деталей составляет {P_2}
в) Вероятность выхода из строя хотя бы одной детали составляет {P_3}
г) Вероятность выхода из строя от одной до двух деталей составляет {P_4}
''')
# Out:
# а) Вероятность выхода из строя всех деталей составляет 0.005000000000000001
# б) Вероятность выхода из строя двух деталей составляет 0.095
# в) Вероятность выхода из строя хотя бы одной детали составляет 0.45999999999999996
# г) Вероятность выхода из строя от одной до двух деталей составляет 0.45499999999999996
